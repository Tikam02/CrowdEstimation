# %%
import h5py
import scipy.io as io
import PIL.Image as Image
import numpy as np
import os
import glob
from matplotlib import pyplot as plt
from scipy.ndimage.filters import gaussian_filter 
import scipy
import json
from matplotlib import cm as CM
from image import *
from model import CSRNet
import torch
# %matplotlib inline

# %%
#this is borrowed from https://github.com/davideverona/deep-crowd-counting_crowdnet
def gaussian_filter_density(gt):
    print gt.shape
    density = np.zeros(gt.shape, dtype=np.float32)
    gt_count = np.count_nonzero(gt)
    if gt_count == 0:
        return density

    pts = np.array(zip(np.nonzero(gt)[1], np.nonzero(gt)[0]))
    leafsize = 2048
    # build kdtree
    tree = scipy.spatial.KDTree(pts.copy(), leafsize=leafsize)
    # query kdtree
    distances, locations = tree.query(pts, k=4)

    print 'generate density...'
    for i, pt in enumerate(pts):
        pt2d = np.zeros(gt.shape, dtype=np.float32)
        pt2d[pt[1],pt[0]] = 1.
        if gt_count > 1:
            sigma = (distances[i][1]+distances[i][2]+distances[i][3])*0.1
        else:
            sigma = np.average(np.array(gt.shape))/2./2. #case: 1 point
        density += scipy.ndimage.filters.gaussian_filter(pt2d, sigma, mode='constant')
    print 'done.'
    return density

# %%
#set the root to the Shanghai dataset you download
root = '/home/tikam/ML/Crowd-count/final/CSRNet/data/'

# %%
#now generate the ShanghaiA's ground truth
part_A_train = os.path.join(root,'part_A_final/train_data','images')
#part_A_test = os.path.join(root,'part_A_final/test_data','images')
#part_B_train = os.path.join(root,'part_B_final/train_data','images')
part_B_test = os.path.join(root,'part_B_final/test_data','images')
path_sets = [part_A_train]

# %%
img_paths = []
for path in path_sets:
    for img_path in glob.glob(os.path.join(path, '*.jpg')):
        img_paths.append(img_path)

# %%
for img_path in img_paths:
    print img_path
    mat = io.loadmat(img_path.replace('.jpg','.mat').replace('images','ground_truth').replace('IMG_','GT_IMG_'))
    img= plt.imread(img_path)
    k = np.zeros((img.shape[0],img.shape[1]))
    gt = mat["image_info"][0,0][0,0][0]
    for i in range(0,len(gt)):
        if int(gt[i][1])<img.shape[0] and int(gt[i][0])<img.shape[1]:
            k[int(gt[i][1]),int(gt[i][0])]=1
    k = gaussian_filter_density(k)
    with h5py.File(img_path.replace('.jpg','.h5').replace('images','ground_truth'), 'w') as hf:
            hf['density'] = k
# Out:
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_A_final/train_data/images/IMG_203.jpg
# (683, 1024)
# generate density...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-ebc551fdcf78> in <module>()
#       8         if int(gt[i][1])<img.shape[0] and int(gt[i][0])<img.shape[1]:
#       9             k[int(gt[i][1]),int(gt[i][0])]=1
# ---> 10     k = gaussian_filter_density(k)
#      11     with h5py.File(img_path.replace('.jpg','.h5').replace('images','ground_truth'), 'w') as hf:
#      12             hf['density'] = k
#
# <ipython-input-2-eef4ae1633bf> in gaussian_filter_density(gt)
#      22         else:
#      23             sigma = np.average(np.array(gt.shape))/2./2. #case: 1 point
# ---> 24         density += scipy.ndimage.filters.gaussian_filter(pt2d, sigma, mode='constant')
#      25     print 'done.'
#      26     return density
#
# /home/tikam/ML/2env/local/lib/python2.7/site-packages/scipy/ndimage/filters.pyc in gaussian_filter(input, sigma, order, output, mode, cval, truncate)
#     284         for axis, sigma, order, mode in axes:
#     285             gaussian_filter1d(input, sigma, axis, order, output,
# --> 286                               mode, cval, truncate)
#     287             input = output
#     288     else:
#
# /home/tikam/ML/2env/local/lib/python2.7/site-packages/scipy/ndimage/filters.pyc in gaussian_filter1d(input, sigma, axis, order, output, mode, cval, truncate)
#     202     # Since we are calling correlate, not convolve, revert the kernel
#     203     weights = _gaussian_kernel1d(sigma, order, lw)[::-1]
# --> 204     return correlate1d(input, weights, axis, output, mode, cval, 0)
#     205
#     206
#
# /home/tikam/ML/2env/local/lib/python2.7/site-packages/scipy/ndimage/filters.pyc in correlate1d(input, weights, axis, output, mode, cval, origin)
#      90     mode = _ni_support._extend_mode_to_code(mode)
#      91     _nd_image.correlate1d(input, weights, axis, output, mode, cval,
# ---> 92                           origin)
#      93     return output
#      94
#
# KeyboardInterrupt:

# %%
img='/home/tikam/ML/Crowd-count/final/CSRNet/data/part_A_final/train_data/images/IMG_5.jpg'

# %%
plt.imshow(Image.open(img))

# %%
gt_file = h5py.File(img.replace('.jpg','.h5').replace('images','ground_truth'),'r')
groundtruth = np.asarray(gt_file['density'])
plt.imshow(groundtruth,cmap=CM.jet)
plt.show()

# %%
np.sum(groundtruth)# don't mind this slight variation
# Out:
# 331.47385

# %%
#now generate the ShanghaiB's ground truth
path_sets = [part_B_train,part_B_test]

# %%
img_paths = []
for path in path_sets:
    for img_path in glob.glob(os.path.join(path, '*.jpg')):
        img_paths.append(img_path)

# %%
for img_path in img_paths:
    print img_path
    mat = io.loadmat(img_path.replace('.jpg','.mat').replace('images','ground_truth').replace('IMG_','GT_IMG_'))
    img= plt.imread(img_path)
    k = np.zeros((img.shape[0],img.shape[1]))
    gt = mat["image_info"][0,0][0,0][0]
    for i in range(0,len(gt)):
        if int(gt[i][1])<img.shape[0] and int(gt[i][0])<img.shape[1]:
            k[int(gt[i][1]),int(gt[i][0])]=1
    k = gaussian_filter(k,15)
    with h5py.File(img_path.replace('.jpg','.h5').replace('images','ground_truth'), 'w') as hf:
            hf['density'] = k
# Out:
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_203.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_230.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_90.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_290.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_149.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_88.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_135.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_364.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_48.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_330.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_85.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_52.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_33.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_30.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_74.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_273.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_58.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_150.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_153.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_107.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_263.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_207.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_222.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_359.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_109.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_365.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_224.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_168.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_336.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_316.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_361.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_51.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_248.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_262.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_293.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_105.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_77.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_62.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_269.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_229.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_342.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_255.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_171.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_40.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_375.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_388.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_350.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_205.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_49.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_118.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_385.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_264.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_306.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_191.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_376.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_371.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_380.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_393.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_199.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_254.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_250.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_32.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_120.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_395.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_319.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_179.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_400.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_288.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_389.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_41.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_314.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_399.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_69.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_315.jpg
# /home/tikam/ML/Crowd-count/final/CSRNet/data/part_B_final/train_data/images/IMG_341.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-1c3d3d10265a> in <module>()
#       8         if int(gt[i][1])<img.shape[0] and int(gt[i][0])<img.shape[1]:
#       9             k[int(gt[i][1]),int(gt[i][0])]=1
# ---> 10     k = gaussian_filter(k,15)
#      11     with h5py.File(img_path.replace('.jpg','.h5').replace('images','ground_truth'), 'w') as hf:
#      12             hf['density'] = k
#
# /home/tikam/ML/2env/local/lib/python2.7/site-packages/scipy/ndimage/filters.pyc in gaussian_filter(input, sigma, order, output, mode, cval, truncate)
#     284         for axis, sigma, order, mode in axes:
#     285             gaussian_filter1d(input, sigma, axis, order, output,
# --> 286                               mode, cval, truncate)
#     287             input = output
#     288     else:
#
# /home/tikam/ML/2env/local/lib/python2.7/site-packages/scipy/ndimage/filters.pyc in gaussian_filter1d(input, sigma, axis, order, output, mode, cval, truncate)
#     202     # Since we are calling correlate, not convolve, revert the kernel
#     203     weights = _gaussian_kernel1d(sigma, order, lw)[::-1]
# --> 204     return correlate1d(input, weights, axis, output, mode, cval, 0)
#     205
#     206
#
# /home/tikam/ML/2env/local/lib/python2.7/site-packages/scipy/ndimage/filters.pyc in correlate1d(input, weights, axis, output, mode, cval, origin)
#      90     mode = _ni_support._extend_mode_to_code(mode)
#      91     _nd_image.correlate1d(input, weights, axis, output, mode, cval,
# ---> 92                           origin)
#      93     return output
#      94
#
# KeyboardInterrupt:

# %%
# Out:
# '/home/tikam/Crowd-count/final/CSRNet/data/part_A_final/train_data/images/IMG_300.jpg'

# %%
import json
path = {u"answer": [42.2], u"abs": 42}
print(json.dumps(path))
# Out:
# {"answer": [42.2], "abs": 42}
